# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./JavaTop50000.csv')

# %%
data.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  11227809           1        11227902.0       NaN  2012-06-27 13:51:36
# 1   6841333           1         6841479.0       NaN  2011-07-27 08:15:58
# 2     40480           1               NaN       NaN  2008-09-02 20:14:29
# 3    309424           1          309448.0       NaN  2008-11-21 16:47:40
# 4    271526           1          271874.0       NaN  2008-11-07 08:31:40
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  24856    1528592
# 1           NaN   6935     667557
# 2           NaN   6724    2024594
# 3           NaN   4156    2158738
# 4           NaN   4081    1267072
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>Here is a piece of C++ code that shows some...      87234.0  ...
# 1  <p>If I run the following program, which parse...     342235.0  ...
# 2  <p>I always thought Java uses <strong>pass-by-...       4315.0  ...
# 3  <p>If you have a <code>java.io.InputStream</co...      16616.0  ...
# 4  <p>I use <code>object != null</code> a lot to ...      34856.0  ...
#
#   ClosedDate   CommunityOwnedDate ContentLicense    PostId TagId Id.1 TagName  \
# 0        NaN                  NaN   CC BY-SA 4.0  11227809    17   17    java
# 1        NaN                  NaN   CC BY-SA 4.0   6841333    17   17    java
# 2        NaN  2012-09-14 18:22:55   CC BY-SA 4.0     40480    17   17    java
# 3        NaN                  NaN   CC BY-SA 4.0    309424    17   17    java
# 4        NaN  2011-10-21 09:02:37   CC BY-SA 4.0    271526    17   17    java
#
#      Count  ExcerptPostId  WikiPostId
# 0  1715860        3624966     3607018
# 1  1715860        3624966     3607018
# 2  1715860        3624966     3607018
# 3  1715860        3624966     3607018
# 4  1715860        3624966     3607018
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     50000 non-null  int64
#  1   PostTypeId             50000 non-null  int64
#  2   AcceptedAnswerId       40342 non-null  float64
#  3   ParentId               0 non-null      float64
#  4   CreationDate           50000 non-null  object
#  5   DeletionDate           0 non-null      float64
#  6   Score                  50000 non-null  int64
#  7   ViewCount              50000 non-null  int64
#  8   Body                   50000 non-null  object
#  9   OwnerUserId            48894 non-null  float64
#  10  OwnerDisplayName       3204 non-null   object
#  11  LastEditorUserId       37621 non-null  float64
#  12  LastEditorDisplayName  1895 non-null   object
#  13  LastEditDate           38097 non-null  object
#  14  LastActivityDate       50000 non-null  object
#  15  Title                  50000 non-null  object
#  16  Tags                   50000 non-null  object
#  17  AnswerCount            50000 non-null  int64
#  18  CommentCount           50000 non-null  int64
#  19  FavoriteCount          48090 non-null  float64
#  20  ClosedDate             4284 non-null   object
#  21  CommunityOwnedDate     288 non-null    object
#  22  ContentLicense         50000 non-null  object
#  23  PostId                 50000 non-null  int64
#  24  TagId                  50000 non-null  int64
#  25  Id.1                   50000 non-null  int64
#  26  TagName                50000 non-null  object
#  27  Count                  50000 non-null  int64
#  28  ExcerptPostId          50000 non-null  int64
#  29  WikiPostId             50000 non-null  int64
# dtypes: float64(6), int64(12), object(12)
# memory usage: 11.4+ MB

# %%
data.describe()
# Out:
#                  Id  PostTypeId  AcceptedAnswerId  ParentId  DeletionDate  \
# count  5.000000e+04     50000.0      4.034200e+04       0.0           0.0
# mean   1.559033e+07         1.0      1.543397e+07       NaN           NaN
# std    1.402733e+07         0.0      1.398485e+07       NaN           NaN
# min    1.230000e+02         1.0      1.270000e+02       NaN           NaN
# 25%    4.133102e+06         1.0      4.156689e+06       NaN           NaN
# 50%    1.107201e+07         1.0      1.086622e+07       NaN           NaN
# 75%    2.403863e+07         1.0      2.355119e+07       NaN           NaN
# max    6.401965e+07         1.0      6.401984e+07       NaN           NaN
#
#               Score     ViewCount   OwnerUserId  LastEditorUserId  \
# count  50000.000000  5.000000e+04  4.889400e+04      3.762100e+04
# mean      44.113400  5.279131e+04  1.313705e+06      1.458268e+06
# std      160.180578  1.180144e+05  1.695202e+06      1.964252e+06
# min       11.000000  8.300000e+01  1.300000e+01     -1.000000e+00
# 25%       14.000000  8.805000e+03  2.240580e+05      1.452870e+05
# 50%       20.000000  2.267100e+04  6.995590e+05      6.974490e+05
# 75%       37.000000  5.370050e+04  1.675584e+06      1.841973e+06
# max    24856.000000  6.062401e+06  1.432431e+07      1.424347e+07
#
#         AnswerCount  CommentCount  FavoriteCount        PostId    TagId  \
# count  50000.000000  50000.000000   48090.000000  5.000000e+04  50000.0
# mean       5.113860      2.428120      13.535080  1.559033e+07     17.0
# std        4.416601      3.242833      66.830113  1.402733e+07      0.0
# min        0.000000      0.000000       0.000000  1.230000e+02     17.0
# 25%        2.000000      0.000000       3.000000  4.133102e+06     17.0
# 50%        4.000000      1.000000       6.000000  1.107201e+07     17.0
# 75%        6.000000      3.000000      12.000000  2.403863e+07     17.0
# max      100.000000     45.000000   11113.000000  6.401965e+07     17.0
#
#           Id.1      Count  ExcerptPostId  WikiPostId
# count  50000.0    50000.0        50000.0     50000.0
# mean      17.0  1715860.0      3624966.0   3607018.0
# std        0.0        0.0            0.0         0.0
# min       17.0  1715860.0      3624966.0   3607018.0
# 25%       17.0  1715860.0      3624966.0   3607018.0
# 50%       17.0  1715860.0      3624966.0   3607018.0
# 75%       17.0  1715860.0      3624966.0   3607018.0
# max       17.0  1715860.0      3624966.0   3607018.0

# %%
data.AnswerCount.plot(kind='hist',bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.Score.plot(kind='hist',bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.hist(bins=50, figsize=(20,15))
plt.savefig('50khists.png')

# %%
data.ContentLicense.value_counts()
# Out:
# CC BY-SA 3.0    35295
# CC BY-SA 2.5     9526
# CC BY-SA 4.0     5179
# Name: ContentLicense, dtype: int64

# %%
data.CommentCount.hist(bins=50)
# Out:
# <AxesSubplot:>
